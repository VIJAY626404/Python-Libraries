# %% [markdown]
# # Seaborn:
# 1. came after matplotlib
# 2. it used widely
# 3. it is more fashionable

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.histplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_12108\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# here line is called kernal density estimited (kde)

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# C:\Users\vijay\AppData\Local\Temp\ipykernel_14308\1163654811.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.scatterplot(x=tips.total_bill,y=tips.tip)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# insight--> linear relation

# %% [markdown]
# # How many are Smoker

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,hue='smoker')

# %%
# what is the relationship b/w tip and size
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,hue='size')

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,style='smoker')

# %%
sns.relplot(x=tips.total_bill,y=tips.tip,data=tips,style='smoker',hue='time')
# maximum tip is 50 and pay tips 10 came for dinner and its smoker

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Catplot

# %%
sns.catplot(x='day',y = 'total_bill',data=tips)
# insights--> Friday are very less people come

# %%
sns.barplot(x='day',y = 'total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x=tips.total_bill,y = tips.tip)

# %%
# oposite of total_bill--> Distribution of total_bill
# oposite of tip --> Distribution of tip

# %%
sns.jointplot(x=tips.total_bill,y = tips.tip,data=tips,kind='reg')
# regression line--> reg

# %%
sns.jointplot(x=tips.total_bill,y = tips.tip,data=tips,kind='hex')

# %%
sns.jointplot(x=tips.total_bill,y = tips.tip,data=tips,kind='kde')
# contour , used in geophysics,metrological department

# %% [markdown]
# # Pairplot :
# 1. it will plot all the pairwise relationship of the dataframe

# %%
sns.pairplot(tips) # numerical data

# %%
sns.pairplot(tips,hue='sex')  # categorical data

# %%
sns.pairplot(tips,hue='smoker',palette='coolwarm')

# %% [markdown]
# # Box Plot:
# 1. box plot used to determine outliars
# 2. extrem data are outliars

# %%
# 1,2,3,4,5
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# data beyond upper fence and lower fence is called outliars
# upper fence = Q3 + 1.5 x IQR, lower fence = Q1-1.5 x IQR

# %%
sns.boxplot(x='day',y='total_bill',data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,palette='rainbow',orient = 'h')
# Out:
# <Axes: >

# %% [markdown]
# # correlation-->
# . it is  statistical relationhip between two variable using heatmap

# %%
tips_num = tips[['total_bill','tip','size']]

# %%
tips_num.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips_num.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(tips_num.corr(),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,aspect=4)

# %% [markdown]
# # count and bar plot are same

# %%
sns.catplot(x='day',y= 'tip',data=tips,kind='swarm')
# Out:
# C:\Users\vijay\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Pie Chart

# %%
my_explod = (0.0,0.5,0.0)
langs=['c','python','java']
students = [20,100,40]

plt.pie(students,labels=langs,autopct='%1.1f%%',explode=my_explod,shadow=True)
plt.title("Pie Chart")
plt.show()

# %%
tips.boxplot()
